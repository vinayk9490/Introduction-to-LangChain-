# %% [markdown]
# UNDERSTAND THE FOLLOWING TERMINOLOGIES AND IMPLEMENT HERE
#
#
#
# 1. CHAT MESSAGES : HumanMessage, SystemPrompt, AIMessage etc
#
# 2. CHAT MODELS:    Every LLM has its own chat models (in langchain we have init_chat_model function)
#
# 3. BINDING TOOLS : How do we bind external tools to LLM and How exactly LLM does tool call?

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_core.messages import AIMessage, HumanMessage
from pprint import pprint
from langgraph.graph import StateGraph

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    model = "llama-3.3-70b-versatile"
)
res=llm.invoke("Hi")

# %%
res.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 23,
#   'prompt_tokens': 36,
#   'total_tokens': 59,
#   'completion_time': 0.060805898,
#   'completion_tokens_details': None,
#   'prompt_time': 0.002305521,
#   'prompt_tokens_details': None,
#   'queue_time': 0.058114853,
#   'total_time': 0.063111419},
#  'model_name': 'llama-3.3-70b-versatile',
#  'system_fingerprint': 'fp_dae98b5ecb',
#  'service_tier': 'on_demand',
#  'finish_reason': 'stop',
#  'logprobs': None,
#  'model_provider': 'groq'}
