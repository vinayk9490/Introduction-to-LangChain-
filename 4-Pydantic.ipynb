# %%
from langgraph.graph import StateGraph, START, END
from pydantic import BaseModel

# %%
class State(BaseModel):
    name: str

# %%
def example_node(state:State):
    return {"name": "Hello"}

# %%
builder = StateGraph(State)
builder.add_node("example_node", example_node)

builder.add_edge(START, "example_node")
builder.add_edge("example_node", END)

from IPython.display import Image, display
graph = builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
graph.invoke({"name": 1})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 graph.invoke({"name": 1})
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/langgraph/pregel/main.py:3309, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3306             chunks.append(chunk)
#    3307 else:
#    3308     # v1: collect interrupts from updates stream
# -> 3309     for chunk in self.stream(
#    3310         input,
#    3311         config,
#    3312         context=context,
#    3313         stream_mode=(
#    3314             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3315         ),
#    3316         print_mode=print_mode,
#    3317         output_keys=output_keys,
#    3318         interrupt_before=interrupt_before,
#    3319         interrupt_after=interrupt_after,
#    3320         durability=durability,
#    3321         **kwargs,
#    3322     ):
#    3323         if stream_mode == "values":
#    3324             if len(chunk) == 2:
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/langgraph/pregel/main.py:2733, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2726             return waiter
#    2728 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2729 # computation proceeds in steps, while there are channel updates.
#    2730 # Channel updates from step N are only visible in step N+1
#    2731 # channels are guaranteed to be immutable for the duration of the step,
#    2732 # with channel updates applied only at the transition between steps.
# -> 2733 while loop.tick():
#    2734     for task in loop.match_cached_writes():
#    2735         loop.output_writes(task.id, task.writes, cached=True)
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/langgraph/pregel/_loop.py:474, in PregelLoop.tick(self)
#     471     return False
#     473 # prepare next tasks
# --> 474 self.tasks = prepare_next_tasks(
#     475     self.checkpoint,
#     476     self.checkpoint_pending_writes,
#     477     self.nodes,
#     478     self.channels,
#     479     self.managed,
#     480     self.config,
#     481     self.step,
#     482     self.stop,
#     483     for_execution=True,
#     484     manager=self.manager,
#     485     store=self.store,
#     486     checkpointer=self.checkpointer,
#     487     trigger_to_nodes=self.trigger_to_nodes,
#     488     updated_channels=self.updated_channels,
#     489     retry_policy=self.retry_policy,
#     490     cache_policy=self.cache_policy,
#     491 )
#     493 # produce debug output
#     494 if self._checkpointer_put_after_previous is not None:
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/langgraph/pregel/_algo.py:469, in prepare_next_tasks(checkpoint, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, trigger_to_nodes, updated_channels, retry_policy, cache_policy)
#     466 # Check if any processes should be run in next step
#     467 # If so, prepare the values to be passed to them
#     468 for name in candidate_nodes:
# --> 469     if task := prepare_single_task(
#     470         (PULL, name),
#     471         None,
#     472         checkpoint=checkpoint,
#     473         checkpoint_id_bytes=checkpoint_id_bytes,
#     474         checkpoint_null_version=null_version,
#     475         pending_writes=pending_writes,
#     476         processes=processes,
#     477         channels=channels,
#     478         managed=managed,
#     479         config=config,
#     480         step=step,
#     481         stop=stop,
#     482         for_execution=for_execution,
#     483         store=store,
#     484         checkpointer=checkpointer,
#     485         manager=manager,
#     486         input_cache=input_cache,
#     487         cache_policy=cache_policy,
#     488         retry_policy=retry_policy,
#     489     ):
#     490         tasks.append(task)
#     491 return {t.id: t for t in tasks}
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/langgraph/pregel/_algo.py:615, in prepare_single_task(task_path, task_id_checksum, checkpoint, checkpoint_id_bytes, checkpoint_null_version, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, input_cache, cache_policy, retry_policy)
#     613 # create task input
#     614 try:
# --> 615     val = _proc_input(
#     616         proc,
#     617         managed,
#     618         channels,
#     619         for_execution=for_execution,
#     620         input_cache=input_cache,
#     621         scratchpad=scratchpad,
#     622     )
#     623     if val is MISSING:
#     624         return
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/langgraph/pregel/_algo.py:1184, in _proc_input(proc, managed, channels, for_execution, scratchpad, input_cache)
#    1182 # If the process has a mapper, apply it to the value
#    1183 if for_execution and proc.mapper is not None:
# -> 1184     val = proc.mapper(val)
#    1186 # Cache the input value
#    1187 if input_cache is not None:
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/langgraph/graph/state.py:1534, in _coerce_state(schema, input)
#    1533 def _coerce_state(schema: type[_S], input: dict[str, Any]) -> _S:
# -> 1534     return schema(**input)
#
# File ~/LangChain/.venv/lib/python3.14/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for State
# name
#   Input should be a valid string [type=string_type, input_value=1, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# Before task with name 'example_node' and path '('__pregel_pull', 'example_node')'
